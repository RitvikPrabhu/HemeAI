# %% [markdown]
# <a href="https://colab.research.google.com/github/RitvikPrabhu/AutoCBC/blob/master/Disease_detect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**HemeAI: Disease Detection**
#
# ###Author: Ritvik Prabhu and Bhargav Iyer

# %% [markdown]
# Below we will clone our repository. The repository will contain the model files, annotated dataset and setup.py which are all necessary to train the model used for the first milestone of the project.

# %%
# !git clone https://github.com/RitvikPrabhu/AutoCBC.git
# %cd AutoCBC
# !pip install -r requirements.txt
# Out:
# Cloning into 'AutoCBC'...
# remote: Enumerating objects: 3629, done.
# remote: Counting objects: 100% (781/781), done.
# remote: Compressing objects: 100% (695/695), done.
# remote: Total 3629 (delta 95), reused 725 (delta 67), pack-reused 2848
# Receiving objects: 100% (3629/3629), 164.79 MiB | 18.41 MiB/s, done.
# Resolving deltas: 100% (1202/1202), done.
# /content/AutoCBC
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ultralyticsplus==0.0.24
#   Downloading ultralyticsplus-0.0.24-py3-none-any.whl (11 kB)
# Collecting ultralytics==8.0.23
#   Downloading ultralytics-8.0.23-py3-none-any.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.0/262.0 KB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: Flask==2.2.3 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (2.2.3)
# Collecting flask_cors==3.0.10
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Collecting sahi<0.12.0,>=0.11.11
#   Downloading sahi-0.11.13-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.0/101.0 KB 14.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.12.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 KB 12.1 MB/s eta 0:00:00
# Collecting fire
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: tensorboard>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (2.12.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (2.27.1)
# Collecting sentry-sdk
#   Downloading sentry_sdk-1.19.1-py2.py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 27.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (6.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (1.10.1)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (1.22.4)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (4.65.0)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (2.0.0+cu118)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (0.12.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (5.9.4)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (4.7.0.72)
# Requirement already satisfied: torchvision>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (0.15.1+cu118)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.9/dist-packages (from ultralytics==8.0.23->-r requirements.txt (line 2)) (7.34.0)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (3.1.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (6.1.0)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.9/dist-packages (from Flask==2.2.3->-r requirements.txt (line 3)) (8.1.3)
# Requirement already satisfied: Six in /usr/local/lib/python3.9/dist-packages (from flask_cors==3.0.10->-r requirements.txt (line 4)) (1.16.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.12.0->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (3.10.7)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6.0->Flask==2.2.3->-r requirements.txt (line 3)) (3.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2>=3.0->Flask==2.2.3->-r requirements.txt (line 3)) (2.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.2.2->ultralytics==8.0.23->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests>=2.23.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (2.0.12)
# Collecting pybboxes==0.1.6
#   Downloading pybboxes-0.1.6-py3-none-any.whl (24 kB)
# Requirement already satisfied: shapely>=1.8.0 in /usr/local/lib/python3.9/dist-packages (from sahi<0.12.0,>=0.11.11->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (2.0.1)
# Collecting click>=8.0
#   Downloading click-8.0.4-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.5/97.5 KB 15.1 MB/s eta 0:00:00
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.40.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.53.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (2.17.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (67.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.8.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (16.0.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.9/dist-packages (from fire->ultralyticsplus==0.0.24->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (5.7.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.2.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.6 MB/s eta 0:00:00
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.0.38)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.2.6)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7.0->ultralytics==8.0.23->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.4.1->ultralytics==8.0.23->-r requirements.txt (line 2)) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=5532061d821d433a8852e86209bd6af034e879befb0086d5ed104667e1e879c2
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# Successfully built fire
# Installing collected packages: terminaltables, sentry-sdk, pybboxes, jedi, fire, click, sahi, huggingface-hub, flask_cors, thop, ultralytics, ultralyticsplus
#   Attempting uninstall: click
#     Found existing installation: click 8.1.3
#     Uninstalling click-8.1.3:
#       Successfully uninstalled click-8.1.3
# Successfully installed click-8.0.4 fire-0.5.0 flask_cors-3.0.10 huggingface-hub-0.13.4 jedi-0.18.2 pybboxes-0.1.6 sahi-0.11.13 sentry-sdk-1.19.1 terminaltables-3.1.10 thop-0.1.1.post2209072238 ultralytics-8.0.23 ultralyticsplus-0.0.24

# %% [markdown]
# The code below will allows us to reset our directory without having to shutdown the entire runtime

# %%
# !rm -rf AutoCBC/

# %% [markdown]
# Import the necessary files and ensure the hardware is compatible

# %%
import ultralytics
from ultralyticsplus import YOLO, render_result

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.23 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
# !pip install roboflow
from roboflow import Roboflow
rf = Roboflow(api_key="k7t7R1s1qjS9eojgbD50")
#project = rf.workspace("blood-cell-uoqgu").project("hemeai")
#dataset = project.version(1).download("yolov8")

#rf = Roboflow(api_key="k7t7R1s1qjS9eojgbD50")
project = rf.workspace().project("disease-detection-z1mqc")
dataset = project.version(2).download("yolov8")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-1.0.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 KB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.0.0)
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.9/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (6.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (8.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.27.1)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.4.4)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.9/dist-packages (from roboflow) (4.7.0.72)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from roboflow) (2.8.2)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.9/dist-packages (from roboflow) (1.26.15)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->roboflow) (2.0.12)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.15.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=0a213009b691ba21e26217233ca92ddb767f45f5ecb5dd04272de7789b964a87
#   Stored in directory: /root/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-0.10.1 roboflow-1.0.3 wget-3.2
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.23, to fix: `pip install ultralytics<=8.0.20`
# Downloading Dataset Version Zip in Disease-Detection-2 to yolov8: 100% [38905764 / 38905764] bytes
# Extracting Dataset Version Zip to Disease-Detection-2 in yolov8:: 100%|██████████| 2734/2734 [00:00<00:00, 4433.37it/s]

# %%
import os
import shutil

#old_name = r"/content/AutoCBC/Disease-Detection-1/data.yaml"
#new_name = r"/content/AutoCBC/Disease-Detection-1/Disease-data.yaml"
#os.rename(old_name, new_name)

old_name = r"/content/AutoCBC/data.yaml"
new_name = r"/content/AutoCBC/M1data.yaml"
os.rename(old_name, new_name)

shutil.move("/content/AutoCBC/Disease-Detection-2/data.yaml", "/content/AutoCBC/data.yaml") 
shutil.move("/content/AutoCBC/Disease-Detection-2", "/content/AutoCBC/datasets/Disease-Detection-2")
# Out:
# '/content/AutoCBC/datasets/Disease-Detection-2'

# %% [markdown]
# We will load the necessary pretrained YOLO model and train the model to our dataset

# %%
# Load a model
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)
# Use the model

#!yolo task=object-detection mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=50 imgsz=640 optimizer="Adam"
model.train(data="data.yaml", epochs=50, imgsz=640, task = "object-detection", optimizer="Adam")  # train the model
metrics = model.val()  # evaluate model performance on the validation set

# task=detect, mode=train, model=yolov8m.yaml, data=data.yaml, epochs=50, patience=50, batch=16, imgsz=640, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=False, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.1, copy_paste=0.
parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/AutoCBC/datasets/Disease-Detection-2/valid/labels.cache... 265 images, 5 backgrounds, 0 corrupt: 100%|██████████| 265/265 [00:00<?, ?it/s]
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 268, len(boxes) = 287. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 17/17 [00:07<00:00,  2.16it/s]
#                    all        265        287      0.512      0.764      0.564      0.502
#           abnormal_rbc        265         23          1          0     0.0437     0.0351
#        band_neutrophil        265         31      0.357      0.742      0.404      0.379
#               basophil        265         27      0.382      0.741      0.502      0.457
#             eosinophil        265         28       0.49          1      0.906      0.826
#           erythroblast        265         29      0.791      0.828      0.894      0.839
#             lymphocyte        265         30      0.733      0.967      0.916      0.802
#               monocyte        265         38      0.409      0.947      0.692      0.511
#              myelocyte        265         24      0.319       0.75      0.357       0.31
#             neutrophil        265         27      0.256      0.704      0.326      0.314
#   segmented_neutrophil        265         30      0.386      0.967      0.602       0.55
# Speed: 0.3ms pre-process, 20.8ms inference, 0.0ms loss, 1.5ms post-process per image

# %% [markdown]
# We locate the model with the most favorable weights and store in the home directory and name it "CBCWeights.pt". We will use these weights in the model and edit some hyperparameters of the model. We will use this to detect objects using bounding boxes

# %%
model = YOLO('runs/detect/train/weights/best.pt')

# set model parameters
model.overrides['conf'] = 0.25  # NMS confidence threshold
model.overrides['iou'] = 0.45  # NMS IoU threshold
model.overrides['agnostic_nms'] = False  # NMS class-agnostic
model.overrides['max_det'] = 1000  # maximum number of detections per image

# observe results
image_pth = "/content/AutoCBC/datasets/Disease-Detection-2/test/images"
image = os.listdir(image_pth)[0]
#image = "/content/AutoCBC/datasets/Disease-Detection-2/test/images/BA_100102_jpg.rf.6f8454a71b80f91564ba4494e041d87a.jpg"
#image = "datasets/data/Testing/images/BloodImage_00391.jpg"
image_pth_full = image_pth + "/" + image
results = model.predict(image_pth_full)

print(results[0].boxes)
render = render_result(model=model, image=image_pth_full, result=results[0])
render.show()
# Out:
# Ultralytics YOLOv8.0.23 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25845550 parameters, 0 gradients, 78.7 GFLOPs
# image 1/1 /content/AutoCBC/datasets/Disease-Detection-2/test/images/BNE_838349_jpg.rf.268b1fc76f710515983eff6be971ff30.jpg: 640x640 1 eosinophil, 37.2ms
# Speed: 0.6ms pre-process, 37.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# tensor([[197.00000, 210.00000, 443.00000, 455.00000,   0.55965,   3.00000]], device='cuda:0')
# <PIL.Image.Image image mode=RGB size=640x640 at 0x7F94A269BA60>

# %% [markdown]
# We will count the number of objects in each class and find the ratio of cells in each image

# %%
results = model.predict(image, stream=True)
blood_count = {"RBC":0, "WBC":0, "Platelets":0}

for r in results:
    for c in r.boxes.cls:
      if model.names[int(c)] in blood_count.keys():
         blood_count[model.names[int(c)]] += 1

print(blood_count)

results = [blood_count['RBC']/sum(blood_count.values()), blood_count['WBC']/sum(blood_count.values()), blood_count['Platelets']/sum(blood_count.values())]

print(results)
# Out:
# image 1/1 /content/AutoCBC/datasets/data/Testing/images/BloodImage_00391.jpg: 480x640 19 RBCs, 1 WBC, 1 Platelets, 14.2ms
# Speed: 3.1ms pre-process, 14.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# {'RBC': 19, 'WBC': 1, 'Platelets': 1}
# [0.9047619047619048, 0.047619047619047616, 0.047619047619047616]
