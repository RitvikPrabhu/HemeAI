# %%
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
import os

# %% [markdown]
# ## Extract Data from XML

# %%
# Function to get the data from XML Annotation
def extract_info_from_xml(xml_file):
    root = ET.parse(xml_file).getroot()
    
    # Initialise the info dict 
    info_dict = {}
    info_dict['bboxes'] = []

    # Parse the XML Tree
    for elem in root:
        # Get the file name 
        if elem.tag == "filename":
            info_dict['filename'] = elem.text
            
        # Get the image size
        elif elem.tag == "size":
            image_size = []
            for subelem in elem:
                image_size.append(int(subelem.text))
            
            info_dict['image_size'] = tuple(image_size)
        
        # Get details of the bounding box 
        elif elem.tag == "object":
            bbox = {}
            for subelem in elem:
                if subelem.tag == "name":
                    bbox["class"] = subelem.text
                    
                elif subelem.tag == "bndbox":
                    for subsubelem in subelem:
                        bbox[subsubelem.tag] = int(subsubelem.text)            
            info_dict['bboxes'].append(bbox)
    
    return info_dict

# %% [markdown]
# ## Convert the data to YOLO v8 annotations

# %%
# Dictionary that maps class names to IDs
class_name_to_id_mapping = {"RBC": 0,
                           "WBC": 1,
                           "Platelets": 2}

# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict, setVal):
    print_buffer = []
    
    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print("Invalid Class. Must be one from ", class_name_to_id_mapping.keys())
        
        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2 
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])
        
        # Normalise the co-ordinates by the dimensions of the image
        image_w, image_h, image_c = info_dict["image_size"]  
        b_center_x /= image_w 
        b_center_y /= image_h 
        b_width    /= image_w 
        b_height   /= image_h 
        
        #Write the bbox details to the file 
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
        
    # Name of the file which we have to save 
    save_file_name = os.path.join("data/"+ setVal + "/TextAnnotations", info_dict["filename"].replace("jpg", "txt"))
    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))

# %% [markdown]
# ### Prepare the YOLO data set for Training Set

# %%
# Get the annotations
annotations = [os.path.join('data/Training/Annotations', x) for x in os.listdir('data/Training/Annotations') if x[-3:] == "xml"]
annotations.sort()

# Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    # print(info_dict)
    # break
    convert_to_yolov5(info_dict, "Training")
annotations = [os.path.join('data/Training/TextAnnotations', x) for x in os.listdir('data/Training/TextAnnotations') if x[-3:] == "txt"]
annotations
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 608.31it/s]
# ['data/Training/TextAnnotations/BloodImage_00000.txt',
#  'data/Training/TextAnnotations/BloodImage_00001.txt',
#  'data/Training/TextAnnotations/BloodImage_00002.txt',
#  'data/Training/TextAnnotations/BloodImage_00003.txt',
#  'data/Training/TextAnnotations/BloodImage_00004.txt',
#  'data/Training/TextAnnotations/BloodImage_00005.txt',
#  'data/Training/TextAnnotations/BloodImage_00006.txt',
#  'data/Training/TextAnnotations/BloodImage_00007.txt',
#  'data/Training/TextAnnotations/BloodImage_00008.txt',
#  'data/Training/TextAnnotations/BloodImage_00009.txt',
#  'data/Training/TextAnnotations/BloodImage_00010.txt',
#  'data/Training/TextAnnotations/BloodImage_00011.txt',
#  'data/Training/TextAnnotations/BloodImage_00012.txt',
#  'data/Training/TextAnnotations/BloodImage_00013.txt',
#  'data/Training/TextAnnotations/BloodImage_00014.txt',
#  'data/Training/TextAnnotations/BloodImage_00015.txt',
#  'data/Training/TextAnnotations/BloodImage_00016.txt',
#  'data/Training/TextAnnotations/BloodImage_00017.txt',
#  'data/Training/TextAnnotations/BloodImage_00018.txt',
#  'data/Training/TextAnnotations/BloodImage_00019.txt',
#  'data/Training/TextAnnotations/BloodImage_00020.txt',
#  'data/Training/TextAnnotations/BloodImage_00021.txt',
#  'data/Training/TextAnnotations/BloodImage_00022.txt',
#  'data/Training/TextAnnotations/BloodImage_00023.txt',
#  'data/Training/TextAnnotations/BloodImage_00024.txt',
#  'data/Training/TextAnnotations/BloodImage_00026.txt',
#  'data/Training/TextAnnotations/BloodImage_00028.txt',
#  'data/Training/TextAnnotations/BloodImage_00029.txt',
#  'data/Training/TextAnnotations/BloodImage_00030.txt',
#  'data/Training/TextAnnotations/BloodImage_00031.txt',
#  'data/Training/TextAnnotations/BloodImage_00032.txt',
#  'data/Training/TextAnnotations/BloodImage_00033.txt',
#  'data/Training/TextAnnotations/BloodImage_00034.txt',
#  'data/Training/TextAnnotations/BloodImage_00035.txt',
#  'data/Training/TextAnnotations/BloodImage_00036.txt',
#  'data/Training/TextAnnotations/BloodImage_00037.txt',
#  'data/Training/TextAnnotations/BloodImage_00038.txt',
#  'data/Training/TextAnnotations/BloodImage_00039.txt',
#  'data/Training/TextAnnotations/BloodImage_00040.txt',
#  'data/Training/TextAnnotations/BloodImage_00041.txt',
#  'data/Training/TextAnnotations/BloodImage_00042.txt',
#  'data/Training/TextAnnotations/BloodImage_00043.txt',
#  'data/Training/TextAnnotations/BloodImage_00044.txt',
#  'data/Training/TextAnnotations/BloodImage_00045.txt',
#  'data/Training/TextAnnotations/BloodImage_00046.txt',
#  'data/Training/TextAnnotations/BloodImage_00047.txt',
#  'data/Training/TextAnnotations/BloodImage_00048.txt',
#  'data/Training/TextAnnotations/BloodImage_00049.txt',
#  'data/Training/TextAnnotations/BloodImage_00050.txt',
#  'data/Training/TextAnnotations/BloodImage_00052.txt',
#  'data/Training/TextAnnotations/BloodImage_00053.txt',
#  'data/Training/TextAnnotations/BloodImage_00054.txt',
#  'data/Training/TextAnnotations/BloodImage_00055.txt',
#  'data/Training/TextAnnotations/BloodImage_00056.txt',
#  'data/Training/TextAnnotations/BloodImage_00057.txt',
#  'data/Training/TextAnnotations/BloodImage_00058.txt',
#  'data/Training/TextAnnotations/BloodImage_00059.txt',
#  'data/Training/TextAnnotations/BloodImage_00062.txt',
#  'data/Training/TextAnnotations/BloodImage_00063.txt',
#  'data/Training/TextAnnotations/BloodImage_00064.txt',
#  'data/Training/TextAnnotations/BloodImage_00065.txt',
#  'data/Training/TextAnnotations/BloodImage_00066.txt',
#  'data/Training/TextAnnotations/BloodImage_00067.txt',
#  'data/Training/TextAnnotations/BloodImage_00068.txt',
#  'data/Training/TextAnnotations/BloodImage_00069.txt',
#  'data/Training/TextAnnotations/BloodImage_00070.txt',
#  'data/Training/TextAnnotations/BloodImage_00071.txt',
#  'data/Training/TextAnnotations/BloodImage_00072.txt',
#  'data/Training/TextAnnotations/BloodImage_00073.txt',
#  'data/Training/TextAnnotations/BloodImage_00074.txt',
#  'data/Training/TextAnnotations/BloodImage_00075.txt',
#  'data/Training/TextAnnotations/BloodImage_00076.txt',
#  'data/Training/TextAnnotations/BloodImage_00077.txt',
#  'data/Training/TextAnnotations/BloodImage_00078.txt',
#  'data/Training/TextAnnotations/BloodImage_00079.txt',
#  'data/Training/TextAnnotations/BloodImage_00081.txt',
#  'data/Training/TextAnnotations/BloodImage_00082.txt',
#  'data/Training/TextAnnotations/BloodImage_00083.txt',
#  'data/Training/TextAnnotations/BloodImage_00086.txt',
#  'data/Training/TextAnnotations/BloodImage_00087.txt',
#  'data/Training/TextAnnotations/BloodImage_00088.txt',
#  'data/Training/TextAnnotations/BloodImage_00089.txt',
#  'data/Training/TextAnnotations/BloodImage_00090.txt',
#  'data/Training/TextAnnotations/BloodImage_00091.txt',
#  'data/Training/TextAnnotations/BloodImage_00092.txt',
#  'data/Training/TextAnnotations/BloodImage_00093.txt',
#  'data/Training/TextAnnotations/BloodImage_00094.txt',
#  'data/Training/TextAnnotations/BloodImage_00095.txt',
#  'data/Training/TextAnnotations/BloodImage_00097.txt',
#  'data/Training/TextAnnotations/BloodImage_00098.txt',
#  'data/Training/TextAnnotations/BloodImage_00099.txt',
#  'data/Training/TextAnnotations/BloodImage_00100.txt',
#  'data/Training/TextAnnotations/BloodImage_00101.txt',
#  'data/Training/TextAnnotations/BloodImage_00103.txt',
#  'data/Training/TextAnnotations/BloodImage_00104.txt',
#  'data/Training/TextAnnotations/BloodImage_00106.txt',
#  'data/Training/TextAnnotations/BloodImage_00107.txt',
#  'data/Training/TextAnnotations/BloodImage_00108.txt',
#  'data/Training/TextAnnotations/BloodImage_00109.txt',
#  'data/Training/TextAnnotations/BloodImage_00110.txt',
#  'data/Training/TextAnnotations/BloodImage_00111.txt',
#  'data/Training/TextAnnotations/BloodImage_00112.txt',
#  'data/Training/TextAnnotations/BloodImage_00113.txt',
#  'data/Training/TextAnnotations/BloodImage_00114.txt',
#  'data/Training/TextAnnotations/BloodImage_00115.txt',
#  'data/Training/TextAnnotations/BloodImage_00117.txt',
#  'data/Training/TextAnnotations/BloodImage_00120.txt',
#  'data/Training/TextAnnotations/BloodImage_00123.txt',
#  'data/Training/TextAnnotations/BloodImage_00124.txt',
#  'data/Training/TextAnnotations/BloodImage_00125.txt',
#  'data/Training/TextAnnotations/BloodImage_00126.txt',
#  'data/Training/TextAnnotations/BloodImage_00127.txt',
#  'data/Training/TextAnnotations/BloodImage_00130.txt',
#  'data/Training/TextAnnotations/BloodImage_00132.txt',
#  'data/Training/TextAnnotations/BloodImage_00133.txt',
#  'data/Training/TextAnnotations/BloodImage_00134.txt',
#  'data/Training/TextAnnotations/BloodImage_00135.txt',
#  'data/Training/TextAnnotations/BloodImage_00136.txt',
#  'data/Training/TextAnnotations/BloodImage_00137.txt',
#  'data/Training/TextAnnotations/BloodImage_00139.txt',
#  'data/Training/TextAnnotations/BloodImage_00140.txt',
#  'data/Training/TextAnnotations/BloodImage_00141.txt',
#  'data/Training/TextAnnotations/BloodImage_00142.txt',
#  'data/Training/TextAnnotations/BloodImage_00143.txt',
#  'data/Training/TextAnnotations/BloodImage_00144.txt',
#  'data/Training/TextAnnotations/BloodImage_00145.txt',
#  'data/Training/TextAnnotations/BloodImage_00147.txt',
#  'data/Training/TextAnnotations/BloodImage_00148.txt',
#  'data/Training/TextAnnotations/BloodImage_00149.txt',
#  'data/Training/TextAnnotations/BloodImage_00150.txt',
#  'data/Training/TextAnnotations/BloodImage_00152.txt',
#  'data/Training/TextAnnotations/BloodImage_00154.txt',
#  'data/Training/TextAnnotations/BloodImage_00156.txt',
#  'data/Training/TextAnnotations/BloodImage_00157.txt',
#  'data/Training/TextAnnotations/BloodImage_00158.txt',
#  'data/Training/TextAnnotations/BloodImage_00159.txt',
#  'data/Training/TextAnnotations/BloodImage_00160.txt',
#  'data/Training/TextAnnotations/BloodImage_00161.txt',
#  'data/Training/TextAnnotations/BloodImage_00162.txt',
#  'data/Training/TextAnnotations/BloodImage_00163.txt',
#  'data/Training/TextAnnotations/BloodImage_00164.txt',
#  'data/Training/TextAnnotations/BloodImage_00165.txt',
#  'data/Training/TextAnnotations/BloodImage_00166.txt',
#  'data/Training/TextAnnotations/BloodImage_00167.txt',
#  'data/Training/TextAnnotations/BloodImage_00168.txt',
#  'data/Training/TextAnnotations/BloodImage_00169.txt',
#  'data/Training/TextAnnotations/BloodImage_00170.txt',
#  'data/Training/TextAnnotations/BloodImage_00171.txt',
#  'data/Training/TextAnnotations/BloodImage_00172.txt',
#  'data/Training/TextAnnotations/BloodImage_00174.txt',
#  'data/Training/TextAnnotations/BloodImage_00175.txt',
#  'data/Training/TextAnnotations/BloodImage_00176.txt',
#  'data/Training/TextAnnotations/BloodImage_00177.txt',
#  'data/Training/TextAnnotations/BloodImage_00178.txt',
#  'data/Training/TextAnnotations/BloodImage_00179.txt',
#  'data/Training/TextAnnotations/BloodImage_00180.txt',
#  'data/Training/TextAnnotations/BloodImage_00182.txt',
#  'data/Training/TextAnnotations/BloodImage_00183.txt',
#  'data/Training/TextAnnotations/BloodImage_00184.txt',
#  'data/Training/TextAnnotations/BloodImage_00187.txt',
#  'data/Training/TextAnnotations/BloodImage_00189.txt',
#  'data/Training/TextAnnotations/BloodImage_00190.txt',
#  'data/Training/TextAnnotations/BloodImage_00191.txt',
#  'data/Training/TextAnnotations/BloodImage_00192.txt',
#  'data/Training/TextAnnotations/BloodImage_00193.txt',
#  'data/Training/TextAnnotations/BloodImage_00195.txt',
#  'data/Training/TextAnnotations/BloodImage_00196.txt',
#  'data/Training/TextAnnotations/BloodImage_00197.txt',
#  'data/Training/TextAnnotations/BloodImage_00198.txt',
#  'data/Training/TextAnnotations/BloodImage_00199.txt',
#  'data/Training/TextAnnotations/BloodImage_00200.txt',
#  'data/Training/TextAnnotations/BloodImage_00201.txt',
#  'data/Training/TextAnnotations/BloodImage_00202.txt',
#  'data/Training/TextAnnotations/BloodImage_00203.txt',
#  'data/Training/TextAnnotations/BloodImage_00204.txt',
#  'data/Training/TextAnnotations/BloodImage_00205.txt',
#  'data/Training/TextAnnotations/BloodImage_00206.txt',
#  'data/Training/TextAnnotations/BloodImage_00207.txt',
#  'data/Training/TextAnnotations/BloodImage_00208.txt',
#  'data/Training/TextAnnotations/BloodImage_00209.txt',
#  'data/Training/TextAnnotations/BloodImage_00210.txt',
#  'data/Training/TextAnnotations/BloodImage_00211.txt',
#  'data/Training/TextAnnotations/BloodImage_00212.txt',
#  'data/Training/TextAnnotations/BloodImage_00214.txt',
#  'data/Training/TextAnnotations/BloodImage_00215.txt',
#  'data/Training/TextAnnotations/BloodImage_00216.txt',
#  'data/Training/TextAnnotations/BloodImage_00217.txt',
#  'data/Training/TextAnnotations/BloodImage_00218.txt',
#  'data/Training/TextAnnotations/BloodImage_00219.txt',
#  'data/Training/TextAnnotations/BloodImage_00220.txt',
#  'data/Training/TextAnnotations/BloodImage_00221.txt',
#  'data/Training/TextAnnotations/BloodImage_00222.txt',
#  'data/Training/TextAnnotations/BloodImage_00223.txt',
#  'data/Training/TextAnnotations/BloodImage_00224.txt',
#  'data/Training/TextAnnotations/BloodImage_00225.txt',
#  'data/Training/TextAnnotations/BloodImage_00226.txt',
#  'data/Training/TextAnnotations/BloodImage_00227.txt',
#  'data/Training/TextAnnotations/BloodImage_00228.txt',
#  'data/Training/TextAnnotations/BloodImage_00229.txt',
#  'data/Training/TextAnnotations/BloodImage_00230.txt',
#  'data/Training/TextAnnotations/BloodImage_00231.txt',
#  'data/Training/TextAnnotations/BloodImage_00232.txt',
#  'data/Training/TextAnnotations/BloodImage_00233.txt',
#  'data/Training/TextAnnotations/BloodImage_00234.txt',
#  'data/Training/TextAnnotations/BloodImage_00235.txt',
#  'data/Training/TextAnnotations/BloodImage_00236.txt',
#  'data/Training/TextAnnotations/BloodImage_00237.txt',
#  'data/Training/TextAnnotations/BloodImage_00239.txt',
#  'data/Training/TextAnnotations/BloodImage_00240.txt',
#  'data/Training/TextAnnotations/BloodImage_00241.txt',
#  'data/Training/TextAnnotations/BloodImage_00242.txt',
#  'data/Training/TextAnnotations/BloodImage_00243.txt',
#  'data/Training/TextAnnotations/BloodImage_00244.txt',
#  'data/Training/TextAnnotations/BloodImage_00245.txt',
#  'data/Training/TextAnnotations/BloodImage_00246.txt',
#  'data/Training/TextAnnotations/BloodImage_00247.txt',
#  'data/Training/TextAnnotations/BloodImage_00248.txt',
#  'data/Training/TextAnnotations/BloodImage_00249.txt',
#  'data/Training/TextAnnotations/BloodImage_00250.txt',
#  'data/Training/TextAnnotations/BloodImage_00251.txt',
#  'data/Training/TextAnnotations/BloodImage_00252.txt',
#  'data/Training/TextAnnotations/BloodImage_00253.txt',
#  'data/Training/TextAnnotations/BloodImage_00254.txt',
#  'data/Training/TextAnnotations/BloodImage_00255.txt',
#  'data/Training/TextAnnotations/BloodImage_00256.txt',
#  'data/Training/TextAnnotations/BloodImage_00257.txt',
#  'data/Training/TextAnnotations/BloodImage_00258.txt',
#  'data/Training/TextAnnotations/BloodImage_00259.txt',
#  'data/Training/TextAnnotations/BloodImage_00260.txt',
#  'data/Training/TextAnnotations/BloodImage_00261.txt',
#  'data/Training/TextAnnotations/BloodImage_00262.txt',
#  'data/Training/TextAnnotations/BloodImage_00263.txt',
#  'data/Training/TextAnnotations/BloodImage_00264.txt',
#  'data/Training/TextAnnotations/BloodImage_00265.txt',
#  'data/Training/TextAnnotations/BloodImage_00266.txt',
#  'data/Training/TextAnnotations/BloodImage_00267.txt',
#  'data/Training/TextAnnotations/BloodImage_00268.txt',
#  'data/Training/TextAnnotations/BloodImage_00269.txt',
#  'data/Training/TextAnnotations/BloodImage_00270.txt',
#  'data/Training/TextAnnotations/BloodImage_00271.txt',
#  'data/Training/TextAnnotations/BloodImage_00272.txt',
#  'data/Training/TextAnnotations/BloodImage_00273.txt',
#  'data/Training/TextAnnotations/BloodImage_00274.txt',
#  'data/Training/TextAnnotations/BloodImage_00275.txt',
#  'data/Training/TextAnnotations/BloodImage_00276.txt',
#  'data/Training/TextAnnotations/BloodImage_00277.txt',
#  'data/Training/TextAnnotations/BloodImage_00278.txt',
#  'data/Training/TextAnnotations/BloodImage_00279.txt',
#  'data/Training/TextAnnotations/BloodImage_00281.txt',
#  'data/Training/TextAnnotations/BloodImage_00282.txt',
#  'data/Training/TextAnnotations/BloodImage_00283.txt',
#  'data/Training/TextAnnotations/BloodImage_00284.txt',
#  'data/Training/TextAnnotations/BloodImage_00285.txt',
#  'data/Training/TextAnnotations/BloodImage_00287.txt',
#  'data/Training/TextAnnotations/BloodImage_00288.txt',
#  'data/Training/TextAnnotations/BloodImage_00289.txt',
#  'data/Training/TextAnnotations/BloodImage_00290.txt',
#  'data/Training/TextAnnotations/BloodImage_00291.txt',
#  'data/Training/TextAnnotations/BloodImage_00292.txt',
#  'data/Training/TextAnnotations/BloodImage_00293.txt',
#  'data/Training/TextAnnotations/BloodImage_00294.txt',
#  'data/Training/TextAnnotations/BloodImage_00295.txt',
#  'data/Training/TextAnnotations/BloodImage_00296.txt',
#  'data/Training/TextAnnotations/BloodImage_00297.txt',
#  'data/Training/TextAnnotations/BloodImage_00298.txt',
#  'data/Training/TextAnnotations/BloodImage_00299.txt',
#  'data/Training/TextAnnotations/BloodImage_00300.txt',
#  'data/Training/TextAnnotations/BloodImage_00301.txt',
#  'data/Training/TextAnnotations/BloodImage_00302.txt',
#  'data/Training/TextAnnotations/BloodImage_00303.txt',
#  'data/Training/TextAnnotations/BloodImage_00304.txt',
#  'data/Training/TextAnnotations/BloodImage_00305.txt',
#  'data/Training/TextAnnotations/BloodImage_00307.txt',
#  'data/Training/TextAnnotations/BloodImage_00308.txt',
#  'data/Training/TextAnnotations/BloodImage_00309.txt',
#  'data/Training/TextAnnotations/BloodImage_00310.txt',
#  'data/Training/TextAnnotations/BloodImage_00311.txt',
#  'data/Training/TextAnnotations/BloodImage_00312.txt',
#  'data/Training/TextAnnotations/BloodImage_00313.txt',
#  'data/Training/TextAnnotations/BloodImage_00314.txt',
#  'data/Training/TextAnnotations/BloodImage_00315.txt',
#  'data/Training/TextAnnotations/BloodImage_00317.txt',
#  'data/Training/TextAnnotations/BloodImage_00318.txt',
#  'data/Training/TextAnnotations/BloodImage_00319.txt',
#  'data/Training/TextAnnotations/BloodImage_00320.txt',
#  'data/Training/TextAnnotations/BloodImage_00322.txt',
#  'data/Training/TextAnnotations/BloodImage_00323.txt',
#  'data/Training/TextAnnotations/BloodImage_00324.txt',
#  'data/Training/TextAnnotations/BloodImage_00325.txt',
#  'data/Training/TextAnnotations/BloodImage_00326.txt',
#  'data/Training/TextAnnotations/BloodImage_00327.txt',
#  'data/Training/TextAnnotations/BloodImage_00330.txt',
#  'data/Training/TextAnnotations/BloodImage_00331.txt',
#  'data/Training/TextAnnotations/BloodImage_00332.txt',
#  'data/Training/TextAnnotations/BloodImage_00333.txt',
#  'data/Training/TextAnnotations/BloodImage_00334.txt',
#  'data/Training/TextAnnotations/BloodImage_00335.txt',
#  'data/Training/TextAnnotations/BloodImage_00336.txt',
#  'data/Training/TextAnnotations/BloodImage_00337.txt',
#  'data/Training/TextAnnotations/BloodImage_00338.txt']

# %% [markdown]
# ### Prepare the YOLO data set for Testing Set

# %%
# Get the annotations
annotations = [os.path.join('data/Testing/Annotations', x) for x in os.listdir('data/Testing/Annotations') if x[-3:] == "xml"]
annotations.sort()

# Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    # print(info_dict)
    # break
    convert_to_yolov5(info_dict, "Testing")
annotations = [os.path.join('data/Testing/TextAnnotations', x) for x in os.listdir('data/Testing/TextAnnotations') if x[-3:] == "txt"]
annotations
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 523.06it/s]
# ['data/Testing/TextAnnotations/BloodImage_00339.txt',
#  'data/Testing/TextAnnotations/BloodImage_00340.txt',
#  'data/Testing/TextAnnotations/BloodImage_00343.txt',
#  'data/Testing/TextAnnotations/BloodImage_00344.txt',
#  'data/Testing/TextAnnotations/BloodImage_00345.txt',
#  'data/Testing/TextAnnotations/BloodImage_00346.txt',
#  'data/Testing/TextAnnotations/BloodImage_00347.txt',
#  'data/Testing/TextAnnotations/BloodImage_00348.txt',
#  'data/Testing/TextAnnotations/BloodImage_00349.txt',
#  'data/Testing/TextAnnotations/BloodImage_00351.txt',
#  'data/Testing/TextAnnotations/BloodImage_00352.txt',
#  'data/Testing/TextAnnotations/BloodImage_00353.txt',
#  'data/Testing/TextAnnotations/BloodImage_00354.txt',
#  'data/Testing/TextAnnotations/BloodImage_00355.txt',
#  'data/Testing/TextAnnotations/BloodImage_00356.txt',
#  'data/Testing/TextAnnotations/BloodImage_00357.txt',
#  'data/Testing/TextAnnotations/BloodImage_00359.txt',
#  'data/Testing/TextAnnotations/BloodImage_00360.txt',
#  'data/Testing/TextAnnotations/BloodImage_00361.txt',
#  'data/Testing/TextAnnotations/BloodImage_00362.txt',
#  'data/Testing/TextAnnotations/BloodImage_00364.txt',
#  'data/Testing/TextAnnotations/BloodImage_00365.txt',
#  'data/Testing/TextAnnotations/BloodImage_00366.txt',
#  'data/Testing/TextAnnotations/BloodImage_00367.txt',
#  'data/Testing/TextAnnotations/BloodImage_00368.txt',
#  'data/Testing/TextAnnotations/BloodImage_00369.txt',
#  'data/Testing/TextAnnotations/BloodImage_00370.txt',
#  'data/Testing/TextAnnotations/BloodImage_00371.txt',
#  'data/Testing/TextAnnotations/BloodImage_00372.txt',
#  'data/Testing/TextAnnotations/BloodImage_00374.txt',
#  'data/Testing/TextAnnotations/BloodImage_00375.txt',
#  'data/Testing/TextAnnotations/BloodImage_00376.txt',
#  'data/Testing/TextAnnotations/BloodImage_00377.txt',
#  'data/Testing/TextAnnotations/BloodImage_00378.txt',
#  'data/Testing/TextAnnotations/BloodImage_00379.txt',
#  'data/Testing/TextAnnotations/BloodImage_00381.txt',
#  'data/Testing/TextAnnotations/BloodImage_00382.txt',
#  'data/Testing/TextAnnotations/BloodImage_00383.txt',
#  'data/Testing/TextAnnotations/BloodImage_00384.txt',
#  'data/Testing/TextAnnotations/BloodImage_00385.txt',
#  'data/Testing/TextAnnotations/BloodImage_00386.txt',
#  'data/Testing/TextAnnotations/BloodImage_00387.txt',
#  'data/Testing/TextAnnotations/BloodImage_00388.txt',
#  'data/Testing/TextAnnotations/BloodImage_00390.txt',
#  'data/Testing/TextAnnotations/BloodImage_00391.txt',
#  'data/Testing/TextAnnotations/BloodImage_00392.txt',
#  'data/Testing/TextAnnotations/BloodImage_00393.txt',
#  'data/Testing/TextAnnotations/BloodImage_00395.txt',
#  'data/Testing/TextAnnotations/BloodImage_00396.txt',
#  'data/Testing/TextAnnotations/BloodImage_00397.txt',
#  'data/Testing/TextAnnotations/BloodImage_00398.txt',
#  'data/Testing/TextAnnotations/BloodImage_00400.txt',
#  'data/Testing/TextAnnotations/BloodImage_00402.txt',
#  'data/Testing/TextAnnotations/BloodImage_00403.txt',
#  'data/Testing/TextAnnotations/BloodImage_00404.txt',
#  'data/Testing/TextAnnotations/BloodImage_00405.txt',
#  'data/Testing/TextAnnotations/BloodImage_00407.txt',
#  'data/Testing/TextAnnotations/BloodImage_00408.txt',
#  'data/Testing/TextAnnotations/BloodImage_00409.txt',
#  'data/Testing/TextAnnotations/BloodImage_00410.txt']

# %% [markdown]
# ### Prepare the YOLO data set for Validation Set

# %%
# Get the annotations
annotations = [os.path.join('data/Validation/Annotations', x) for x in os.listdir('data/Validation/Annotations') if x[-3:] == "xml"]
annotations.sort()

# Convert and save the annotations
for ann in tqdm(annotations):
    info_dict = extract_info_from_xml(ann)
    # print(info_dict)
    # break
    convert_to_yolov5(info_dict, "Validation")
annotations = [os.path.join('data/Validation/TextAnnotations', x) for x in os.listdir('data/Validation/TextAnnotations') if x[-3:] == "txt"]
annotations
# Out:
# 100%|██████████| 60/60 [00:00<00:00, 296.55it/s]
# ['data/Validation/TextAnnotations/BloodImage_00002.txt',
#  'data/Validation/TextAnnotations/BloodImage_00004.txt',
#  'data/Validation/TextAnnotations/BloodImage_00007.txt',
#  'data/Validation/TextAnnotations/BloodImage_00011.txt',
#  'data/Validation/TextAnnotations/BloodImage_00017.txt',
#  'data/Validation/TextAnnotations/BloodImage_00019.txt',
#  'data/Validation/TextAnnotations/BloodImage_00024.txt',
#  'data/Validation/TextAnnotations/BloodImage_00028.txt',
#  'data/Validation/TextAnnotations/BloodImage_00031.txt',
#  'data/Validation/TextAnnotations/BloodImage_00039.txt',
#  'data/Validation/TextAnnotations/BloodImage_00045.txt',
#  'data/Validation/TextAnnotations/BloodImage_00046.txt',
#  'data/Validation/TextAnnotations/BloodImage_00048.txt',
#  'data/Validation/TextAnnotations/BloodImage_00049.txt',
#  'data/Validation/TextAnnotations/BloodImage_00050.txt',
#  'data/Validation/TextAnnotations/BloodImage_00058.txt',
#  'data/Validation/TextAnnotations/BloodImage_00063.txt',
#  'data/Validation/TextAnnotations/BloodImage_00064.txt',
#  'data/Validation/TextAnnotations/BloodImage_00065.txt',
#  'data/Validation/TextAnnotations/BloodImage_00066.txt',
#  'data/Validation/TextAnnotations/BloodImage_00071.txt',
#  'data/Validation/TextAnnotations/BloodImage_00081.txt',
#  'data/Validation/TextAnnotations/BloodImage_00089.txt',
#  'data/Validation/TextAnnotations/BloodImage_00094.txt',
#  'data/Validation/TextAnnotations/BloodImage_00103.txt',
#  'data/Validation/TextAnnotations/BloodImage_00106.txt',
#  'data/Validation/TextAnnotations/BloodImage_00109.txt',
#  'data/Validation/TextAnnotations/BloodImage_00112.txt',
#  'data/Validation/TextAnnotations/BloodImage_00113.txt',
#  'data/Validation/TextAnnotations/BloodImage_00114.txt',
#  'data/Validation/TextAnnotations/BloodImage_00117.txt',
#  'data/Validation/TextAnnotations/BloodImage_00137.txt',
#  'data/Validation/TextAnnotations/BloodImage_00147.txt',
#  'data/Validation/TextAnnotations/BloodImage_00148.txt',
#  'data/Validation/TextAnnotations/BloodImage_00166.txt',
#  'data/Validation/TextAnnotations/BloodImage_00170.txt',
#  'data/Validation/TextAnnotations/BloodImage_00174.txt',
#  'data/Validation/TextAnnotations/BloodImage_00212.txt',
#  'data/Validation/TextAnnotations/BloodImage_00217.txt',
#  'data/Validation/TextAnnotations/BloodImage_00224.txt',
#  'data/Validation/TextAnnotations/BloodImage_00226.txt',
#  'data/Validation/TextAnnotations/BloodImage_00229.txt',
#  'data/Validation/TextAnnotations/BloodImage_00231.txt',
#  'data/Validation/TextAnnotations/BloodImage_00242.txt',
#  'data/Validation/TextAnnotations/BloodImage_00270.txt',
#  'data/Validation/TextAnnotations/BloodImage_00273.txt',
#  'data/Validation/TextAnnotations/BloodImage_00274.txt',
#  'data/Validation/TextAnnotations/BloodImage_00281.txt',
#  'data/Validation/TextAnnotations/BloodImage_00288.txt',
#  'data/Validation/TextAnnotations/BloodImage_00289.txt',
#  'data/Validation/TextAnnotations/BloodImage_00296.txt',
#  'data/Validation/TextAnnotations/BloodImage_00298.txt',
#  'data/Validation/TextAnnotations/BloodImage_00301.txt',
#  'data/Validation/TextAnnotations/BloodImage_00303.txt',
#  'data/Validation/TextAnnotations/BloodImage_00311.txt',
#  'data/Validation/TextAnnotations/BloodImage_00312.txt',
#  'data/Validation/TextAnnotations/BloodImage_00331.txt',
#  'data/Validation/TextAnnotations/BloodImage_00332.txt',
#  'data/Validation/TextAnnotations/BloodImage_00336.txt',
#  'data/Validation/TextAnnotations/BloodImage_00337.txt']
